# %% [markdown]
# ## Homework 08: Classification
#
# ### Due: Midnight, March 22nd (with usual 2 hour grace period and late policy)
#
# ### Overview
#
# In this final homework before starting our course project, we will introduce the essential machine learning paradigm of **classification**. We will work with the **UCI Adult** dataset. This is a binary classification task.
#
# As we’ve discussed in this week’s lessons, the classification workflow is similar to what we’ve done for regression, with a few key differences:
# - We use `StratifiedKFold` instead of plain `KFold` so that every fold keeps the original class proportions.
# - We use classification metrics (e.g., accuracy, precision, recall, F1-score for binary classification) instead of regression metrics.
# - We could explore misclassified instances through a confusion matrix (though we will not do that in this homework).
#
# For this assignment, you’ll build a gradient boosting classification using `HistGradientBoostingClassifier` (HGBC) and explore ways of tuning the hyperparameters, including using the technique of early stopping, which basically avoiding have to tune the number of estimators (called `max_iter` in HGBC).
#
# HGBC has many advantages, which we explain below.
#
#
# ### Grading
#
# There are 7 graded problems, each worth 7 points, and you get 1 point free if you complete the assignment.

# %%
# General utilities
import os
import io
import time
import zipfile
import requests
from collections import Counter

# Data handling and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from IPython.display import display, HTML, Markdown
 
# Data source
from sklearn.datasets import fetch_openml

 
# scikit-learn core tools 
from sklearn.model_selection import (
    train_test_split,
    cross_val_score,
    StratifiedKFold,
    RandomizedSearchCV
)

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder

 
# Import model 
from sklearn.ensemble import HistGradientBoostingClassifier
 
# Metrics
from sklearn.metrics import balanced_accuracy_score, classification_report
 
# Distributions for random search
from scipy.stats import loguniform, randint, uniform

# pandas dtypes helpers
from pandas.api.types import is_numeric_dtype, is_categorical_dtype
from pandas import CategoricalDtype

# Optuna Hyperparameter Search tool    (may need to be installed)
import optuna


# Misc

random_seed = 42

def format_hms(seconds):
    return time.strftime("%H:%M:%S", time.gmtime(seconds))

# %% [markdown]
# ### Prelude 1: Load and Preprocess the UCI Adult Income Dataset
#
# - Load the dataset from sklearn
# - Preliminary EDA
# - Feature Engineering

# %%
# Load and clean
df = fetch_openml(name='adult', version=2, as_frame=True).frame

df.replace("?", np.nan, inplace=True)            # Some datasets use ? instead of Nan for missing data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       46043 non-null  category
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  category
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  category
#  6   occupation      46033 non-null  category
#  7   relationship    48842 non-null  category
#  8   race            48842 non-null  category
#  9   sex             48842 non-null  category
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  47985 non-null  category
#  14  class           48842 non-null  category
# dtypes: category(9), int64(6)
# memory usage: 2.7 MB

# %% [markdown]
# #### Check: Is the dataset imbalanced?

# %%
print(df['class'].value_counts(normalize=True))
# Out:
# class
# <=50K    0.760718
# >50K     0.239282
# Name: proportion, dtype: float64

# %% [markdown]
# **YES:** It looks like this dataset is somewhat imbalanced. Therefore, we will
# 1. Tell the model to compensate during training by setting `class_weight='balanced'` when defining the model;
# 2. Evaluate it `balanced_accuracy` instead of `accuracy` and with class-aware metrics (precision, recall, F1); and
# 3. [Optional] Adjust the probability threshold instead of relying on raw accuracy alone after examining the precision-recall trade-off you observe at 0.5.

# %% [markdown]
# ### Feature Engineering
#
# Based on the considerations in **Appendix One**, we'll make the following changes to the dataset to facilitate training:
#
#
# 1. Drop `fnlwgt` and `education`.
# 3. Replace `capital-gain` and `capital-loss` by their difference `capital_net` and add a log-scaled version `capital_net_log`.

# %%
# Drop the survey-weight column
df_eng = df.drop(columns=["fnlwgt"])

# Keep only the ordinal education feature
df_eng = df_eng.drop(columns=["education"])      # retain 'education-num'

# Combine capital gains and losses, add a log-scaled variant
df_eng["capital_net"]     = df_eng["capital-gain"] - df_eng["capital-loss"]
df_eng["capital_net_log"] = np.log1p(df_eng["capital_net"].clip(lower=0))
df_eng = df_eng.drop(columns=["capital-gain", "capital-loss"])

# check
df_eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        46043 non-null  category
#  2   education-num    48842 non-null  int64
#  3   marital-status   48842 non-null  category
#  4   occupation       46033 non-null  category
#  5   relationship     48842 non-null  category
#  6   race             48842 non-null  category
#  7   sex              48842 non-null  category
#  8   hours-per-week   48842 non-null  int64
#  9   native-country   47985 non-null  category
#  10  class            48842 non-null  category
#  11  capital_net      48842 non-null  int64
#  12  capital_net_log  48842 non-null  float64
# dtypes: category(8), float64(1), int64(4)
# memory usage: 2.2 MB

# %% [markdown]
# #### Separate target and split
#
# Create the feature set `X` and the target set `y` (using `class` as the target) and split the dataset into 80% training and 20% testing sets, making sure to stratify.

# %%
X = df_eng.drop(columns=["class"])
y = (df_eng["class"] == ">50K").astype(int)

# Split (with stratification)
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=random_seed,
    stratify=y                           # So same proportion of classes in train and test sets
)

print("Train:", X_train.shape, y_train.shape)
print("Test :", X_test.shape,  y_test.shape)
# Out:
# Train: (39073, 12) (39073,)
# Test : (9769, 12) (9769,)

# %% [markdown]
# ### Prelude 2: Create a data pipeline and the `HistGradientBoostingClassifier` model
#
# Histogram-based gradient boosting improves on the standard version by:
#
# * **Histogram splits:** bins each feature into ≤ `max_bins` quantiles (i.e., each bin is approximately the same size) and tests splits only between bins, slashing compute time and scaling to large data sets. Default for `max_bins` = 255.
# * **Native NaN handling:** treats missing values as their own bin—no imputation needed.
# * **Native Categorical Support**: accepts integer-encoded categories directly and tests “category c vs. all others” splits, eliminating one-hot blow-ups and fake orderings.
# * **Built-in early stopping:** stops training after no improvement in validation loss after `n_iter_no_change` rounds. `tol` defines "improvement" (default is 1e-7).
# * **Leaf shrinkage:** adds `l2_regularization`, which ridge-shrinks each leaf value (without changing tree shape) so tiny, noisy leaves have less effect.
#
# >**Summary:**  Histogram-based GB trades a tiny approximation error (binning) for a **huge speed-up** and adds extra conveniences, making it the preferred choice for large tabular data sets. Tuning workflow relies on **Early stopping** to stop training before overfitting occurs.

# %%
# Define a baseline model 

HGBC_model = HistGradientBoostingClassifier(
    # tree structure and learning rate
    learning_rate=0.1,            # These 5 parameters are at defaults for our baseline training in Problem 1             
    max_leaf_nodes=31,            # but will be tuned by randomized search in Problem 2 and Optuna in Problem 3               
    max_depth=None,               
    min_samples_leaf=20,          
    l2_regularization=0.0,        

    # bins and iteration
    max_bins=255,                 # default
    max_iter=500,                 # high enough for early stopping
    early_stopping=True,
    n_iter_no_change=20,
    validation_fraction=0.2,      # 20% monitored for early stopping
    tol=1e-7,                     # default tolerance for validation improvement

    # class imbalance
    class_weight="balanced",

    random_state=random_seed,
    verbose=0
)

# %% [markdown]
# ### Create a pipeline appropriate for HGBC
#
# **Why use a `Pipeline` instead of encoding in the dataset first?**
#
# * **Avoid data leakage.** In each CV fold, the `OrdinalEncoder` is refit only on that fold’s training data, so the validation split never influences the encoder.
# * **Single, reusable object.** The pipeline bundles preprocessing + model, letting you call `fit`/`predict` on raw data anywhere (CV, Optuna, production) with identical behavior.
# * **Compatible with search tools.** `cross_validate`, `GridSearchCV`, and Optuna expect an estimator that can be cloned and refit; a pipeline meets that requirement automatically.
#
# Put simply, the pipeline gives you leak-free evaluation and portable, hassle-free tuning without extra code.

# %%
enc = OrdinalEncoder(
    handle_unknown="use_encoded_value",   # Allow unseen categories during transform
    unknown_value=-1,                     # Code for unseen categories
    encoded_missing_value=-2,             # Code for missing values (NaN)
    dtype=np.int64                        # Needed for HistGradientBoostingClassifier
)

# Categorical features
cat_cols = X.select_dtypes(exclude=["number"]).columns.tolist()

# Numeric features (everything that isn’t object / category)
num_cols = X.select_dtypes(include=["number"]).columns.tolist()

preprocess = ColumnTransformer(
    [("cat", enc, cat_cols),
     ("num", "passthrough", num_cols)]
)

pipelined_model = Pipeline([
    ("prep", preprocess),
    ("gb",   HGBC_model)
])

# %% [markdown]
# ## Problem 1: Baseline Cross-Validation with F1
#
# In this problem, you will run a baseline cross-validation evaluation of your `HistGradientBoostingClassifier` pipeline, using `HGBC_model` defined above.
#
# **Background:**
#
# * Since the Adult dataset is imbalanced (about 24% positives, 76% negatives), accuracy alone is not reliable.
# * We will use the **F1 score** as the evaluation metric, since it balances precision (avoiding false positives) and recall (avoiding false negatives) in a single measure. This is a fairer metric for imbalanced classification, where both types of error matter.
# * We will apply **5-fold stratified cross-validation** to make sure each fold has the same proportion of the classes as the original dataset.
# * Repeated cross-validation is optional and not required here, because the Adult dataset is large and `HistGradientBoostingClassifier` is robust to small sampling differences.
#
# **Instructions:**
#
# 1. Set up a `StratifiedKFold` cross-validation object with 5 splits, shuffling enabled, and `random_state=random_seed`.
# 2. Use `cross_val_score` to estimate the mean F1 score and its standard deviation across the folds.
# 3. Print out the mean and standard deviation of the F1 score, rounded to 4 decimal places.
# 4. Answer the graded question.

# %%
# Your code here

##__cv
cv = StratifiedKFold( 
    n_splits= 5 
    , shuffle= True
    , random_state= random_seed
)

##__ cross_val_score
score_q1 = cross_val_score(
    pipelined_model
    , X_train, y_train
    , cv=cv
    , scoring="f1"
    , n_jobs= -2    
)

# %%
print(f"Mean CV F1: {score_q1.mean():.4f} ± {score_q1.std():.4f}")
# Out:
# Mean CV F1: 0.7123 ± 0.0035

# %% [markdown]
# ### Problem 1 Graded Answer
#
# Set `a1` to the mean F1 score of the baseline model.

# %%
 # Your answer here

a1 = score_q1.mean()                    # replace 0 with an expression

# %%
# DO NOT change this cell in any way

print(f'a1 = {a1:.4f}')
# Out:
# a1 = 0.7123

# %% [markdown]
# ## Problem 2: Hyperparameter Optimization with Randomized Search for F1
#
# In this problem, you will tune your `pipelined_model` using `RandomizedSearchCV` to identify the best combination of tree structure and learning rate parameters that maximize the **F1 score**.
#
# **Background:**
# The F1 score is our main metric because it balances precision and recall on an imbalanced dataset. Optimizing hyperparameters for F1 ensures we manage both false positives and false negatives in a single measure.
#
# **Instructions:**
#
# 1. Set up a randomized search over the following hyperparameter ranges, using appropriate random-number distributions:
#
#    * `learning_rate` (log-uniform between 1e-3 and 0.3)
#    * `max_leaf_nodes` (integer from 16 to 256)
#    * `max_depth` (integer from 2 to 10)
#    * `min_samples_leaf` (integer from 10 to 200)
#    * `l2_regularization` (uniform between 0.0 and 2.0)
# 2. Use **5-fold stratified cross-validation**, with the same settings as in Problem 1.
# 3. Start `n_iter` at 10 or 20 to prototype, but try for 50 - 100 trials. More trials will generally yield better results, if your time and machine allow.
# 4. After running the search, show a neatly formatted table of the top 5 results, using `display(...)` showing their mean F1 scores, standard deviation, and the chosen hyperparameter values.
# 5. Answer the graded question.

# %%
# Your code here

parameter_rscv = {
    "gb__learning_rate": loguniform(1e-3, 0.3) 
    , "gb__max_leaf_nodes": range(16, 256) 
    , "gb__max_depth": range(2,10) 
    , "gb__min_samples_leaf": range(10, 200) 
    , "gb__l2_regularization": uniform(0,2)
}

# n_iter_todo = 20  
n_iter_todo = 100 


score_q2 = RandomizedSearchCV( 
    estimator= pipelined_model 
    , param_distributions= parameter_rscv
    , n_iter= n_iter_todo
    , n_jobs= -2
    , cv = cv 
    , scoring="f1"
    , verbose=1 
    , random_state= random_seed
)

score_q2.fit(X_train, y_train)


##---

df_q2 = pd.DataFrame(score_q2.cv_results_)
df_q2_summ = (df_q2
              .filter(items=[ "mean_test_score", "std_test_score" , "params"]) 
              .sort_values(by="mean_test_score", ascending=False)
              .head(5)
)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits

# %%
display(df_q2_summ.style.background_gradient(cmap="viridis"))
# Out:
# <style type="text/css">
# #T_7f74b_row0_col0, #T_7f74b_row2_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_7f74b_row0_col1 {
#   background-color: #b5de2b;
#   color: #000000;
# }
# #T_7f74b_row1_col0 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_7f74b_row1_col1 {
#   background-color: #77d153;
#   color: #000000;
# }
# #T_7f74b_row2_col0 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_7f74b_row3_col0 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_7f74b_row3_col1 {
#   background-color: #9dd93b;
#   color: #000000;
# }
# #T_7f74b_row4_col0, #T_7f74b_row4_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7f74b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f74b_level0_col0" class="col_heading level0 col0" >mean_test_score</th>
#       <th id="T_7f74b_level0_col1" class="col_heading level0 col1" >std_test_score</th>
#       <th id="T_7f74b_level0_col2" class="col_heading level0 col2" >params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f74b_level0_row0" class="row_heading level0 row0" >37</th>
#       <td id="T_7f74b_row0_col0" class="data row0 col0" >0.712122</td>
#       <td id="T_7f74b_row0_col1" class="data row0 col1" >0.003238</td>
#       <td id="T_7f74b_row0_col2" class="data row0 col2" >{'gb__l2_regularization': np.float64(0.727259204758588), 'gb__learning_rate': np.float64(0.2554006816661351), 'gb__max_depth': 5, 'gb__max_leaf_nodes': 27, 'gb__min_samples_leaf': 48}</td>
#     </tr>
#     <tr>
#       <th id="T_7f74b_level0_row1" class="row_heading level0 row1" >51</th>
#       <td id="T_7f74b_row1_col0" class="data row1 col0" >0.712020</td>
#       <td id="T_7f74b_row1_col1" class="data row1 col1" >0.003146</td>
#       <td id="T_7f74b_row1_col2" class="data row1 col2" >{'gb__l2_regularization': np.float64(0.18620553561179842), 'gb__learning_rate': np.float64(0.16692147899724186), 'gb__max_depth': 6, 'gb__max_leaf_nodes': 175, 'gb__min_samples_leaf': 18}</td>
#     </tr>
#     <tr>
#       <th id="T_7f74b_level0_row2" class="row_heading level0 row2" >66</th>
#       <td id="T_7f74b_row2_col0" class="data row2 col0" >0.711805</td>
#       <td id="T_7f74b_row2_col1" class="data row2 col1" >0.003347</td>
#       <td id="T_7f74b_row2_col2" class="data row2 col2" >{'gb__l2_regularization': np.float64(1.9333096380873391), 'gb__learning_rate': np.float64(0.24378306148710702), 'gb__max_depth': 2, 'gb__max_leaf_nodes': 131, 'gb__min_samples_leaf': 169}</td>
#     </tr>
#     <tr>
#       <th id="T_7f74b_level0_row3" class="row_heading level0 row3" >72</th>
#       <td id="T_7f74b_row3_col0" class="data row3 col0" >0.711772</td>
#       <td id="T_7f74b_row3_col1" class="data row3 col1" >0.003205</td>
#       <td id="T_7f74b_row3_col2" class="data row3 col2" >{'gb__l2_regularization': np.float64(1.6187223109570272), 'gb__learning_rate': np.float64(0.10156617769867014), 'gb__max_depth': 2, 'gb__max_leaf_nodes': 167, 'gb__min_samples_leaf': 22}</td>
#     </tr>
#     <tr>
#       <th id="T_7f74b_level0_row4" class="row_heading level0 row4" >95</th>
#       <td id="T_7f74b_row4_col0" class="data row4 col0" >0.711707</td>
#       <td id="T_7f74b_row4_col1" class="data row4 col1" >0.002373</td>
#       <td id="T_7f74b_row4_col2" class="data row4 col2" >{'gb__l2_regularization': np.float64(1.8877832091215143), 'gb__learning_rate': np.float64(0.21828590870797615), 'gb__max_depth': 5, 'gb__max_leaf_nodes': 143, 'gb__min_samples_leaf': 169}</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_q2[['mean_test_score' , "std_test_score" , 'rank_test_score']].sort_index().head(5)
# Out:
#    mean_test_score  std_test_score  rank_test_score
# 0         0.710646        0.002664               21
# 1         0.702358        0.001820               50
# 2         0.650608        0.003850               94
# 3         0.709147        0.001655               40
# 4         0.681315        0.004553               65

# %%
print(df_q2['mean_test_score'].max())
# Out:
# 0.7121222889240192

# %% [markdown]
# ### Problem 2 Graded Answer
#
# Set `a2` to the mean F1 score of the best model found.

# %%
 # Your answer here

a2 = df_q2['mean_test_score'].max()                     # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a2 = {a2:.4f}')
# Out:
# a2 = 0.7121

# %% [markdown]
# ## Problem 3: Hyperparameter Optimization with Optuna for F1
#
# In this problem, you will explore **Optuna**, a powerful hyperparameter optimization framework, to identify the best combination of hyperparameters that maximize the F1 score of your `pipelined_model`.
#
# **Background:**
# Optuna uses a smarter sampling strategy than grid search or randomized search, allowing you to explore the hyperparameter space more efficiently. It also supports *pruning*, which can stop unpromising trials early to save time. This makes it a popular SOTA optimization tool.
#
# **Before you start** browse the [Optuna documentation](https://optuna.org) and view the [tutorial video](https://optuna.readthedocs.io/en/stable/tutorial/index.html).
#
# As before, we focus on the **F1 score** because it balances precision and recall, making it more robust on an imbalanced dataset.
#
# **Instructions:**
#
# 1. Define an Optuna objective function to optimize F1 score, sampling the exact same hyperparameter ranges you did in Problem 2 and using the same CV settings.
# 3. Set up an Optuna study with a reasonable number of trials (e.g., up to 100 depending on runtime resources--on my machine Optuna runs about 10x faster than randomized search for the same number of trials, but YMMV).
# 4. After running the optimization, `display` a clean table with the top 5 trials showing their F1 scores and corresponding hyperparameter settings.
# 5. Answer the graded question.
#
# **Note:**  There are many resources on Optuna you can find on the web, but for this problem, you have my permission to let ChatGPT write the code for you.

# %%
# Your code here
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Your code here
# ----> 3 asdf
#
# NameError: name 'asdf' is not defined

# %%
def objective(trial):
    params = {
        "gb__learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.3)
        ,"gb__max_leaf_nodes": trial.suggest_int("max_leaf_nodes", 16, 256)
        ,"gb__max_depth": trial.suggest_int("max_depth", 2, 10)
        ,"gb__min_samples_leaf": trial.suggest_int("min_samples_leaf", 10, 200)
        ,"gb__l2_regularization": trial.suggest_float("l2_regularization", 0, 2)
    }

    pipelined_model.set_params(**params)

    score = cross_val_score(
        pipelined_model
        , X_train, y_train
        , cv=cv
        , scoring="f1"
        , n_jobs= -2    
    ).mean()

    return score

optuna.logging.set_verbosity(optuna.logging.WARNING)    ##___just for less output


optunastudy = optuna.create_study(direction="maximize")
optunastudy.optimize(objective, n_trials=100)

df_q3 = pd.DataFrame(optunastudy.trials_dataframe())

df_q3_summ = (df_q3
              .sort_values(by="value", ascending=False)
              .head(5)
)

display(df_q3_summ.style.background_gradient(cmap="viridis"))
# Out:
# [I 2026-03-18 16:02:42,206] A new study created in memory with name: no-name-a11ddd8e-da4e-4945-804c-7534a9181e8a
# [I 2026-03-18 16:02:45,956] Trial 0 finished with value: 0.7124924505996589 and parameters: {'learning_rate': 0.28660061153053906, 'max_leaf_nodes': 34, 'max_depth': 2, 'min_samples_leaf': 70, 'l2_regularization': 0.09284557178144448}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:02:46,952] Trial 1 finished with value: 0.7114391306686318 and parameters: {'learning_rate': 0.2796772895419973, 'max_leaf_nodes': 77, 'max_depth': 6, 'min_samples_leaf': 93, 'l2_regularization': 0.2983257313194161}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:02:49,353] Trial 2 finished with value: 0.7093221301339783 and parameters: {'learning_rate': 0.1012809409488392, 'max_leaf_nodes': 229, 'max_depth': 10, 'min_samples_leaf': 173, 'l2_regularization': 1.6544729086013534}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:02:50,842] Trial 3 finished with value: 0.7106226581703632 and parameters: {'learning_rate': 0.2960456527667357, 'max_leaf_nodes': 147, 'max_depth': 3, 'min_samples_leaf': 82, 'l2_regularization': 1.3145519407912971}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:02:53,554] Trial 4 finished with value: 0.6992193546467695 and parameters: {'learning_rate': 0.03002732269523175, 'max_leaf_nodes': 215, 'max_depth': 3, 'min_samples_leaf': 100, 'l2_regularization': 1.7446190359852431}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:02:55,930] Trial 5 finished with value: 0.7059625046701611 and parameters: {'learning_rate': 0.06327956672200724, 'max_leaf_nodes': 162, 'max_depth': 2, 'min_samples_leaf': 13, 'l2_regularization': 0.8869914011601414}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:02:56,876] Trial 6 finished with value: 0.7088527704214332 and parameters: {'learning_rate': 0.282143185473725, 'max_leaf_nodes': 17, 'max_depth': 6, 'min_samples_leaf': 123, 'l2_regularization': 1.3344779442057864}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:02:57,937] Trial 7 finished with value: 0.7117040282982139 and parameters: {'learning_rate': 0.19844850760544938, 'max_leaf_nodes': 214, 'max_depth': 6, 'min_samples_leaf': 34, 'l2_regularization': 0.9285014205195561}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:02,212] Trial 8 finished with value: 0.6669164418793541 and parameters: {'learning_rate': 0.0024712388607257747, 'max_leaf_nodes': 147, 'max_depth': 6, 'min_samples_leaf': 163, 'l2_regularization': 0.6990134147728229}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:05,216] Trial 9 finished with value: 0.7094315169349096 and parameters: {'learning_rate': 0.06825916247485836, 'max_leaf_nodes': 112, 'max_depth': 6, 'min_samples_leaf': 101, 'l2_regularization': 1.011039395869825}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:06,270] Trial 10 finished with value: 0.7109122221599824 and parameters: {'learning_rate': 0.19884304227813848, 'max_leaf_nodes': 17, 'max_depth': 9, 'min_samples_leaf': 57, 'l2_regularization': 0.061345895982530256}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:07,391] Trial 11 finished with value: 0.7097897858863058 and parameters: {'learning_rate': 0.20964544413112793, 'max_leaf_nodes': 253, 'max_depth': 8, 'min_samples_leaf': 26, 'l2_regularization': 0.436980371534055}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:08,743] Trial 12 finished with value: 0.7098129536251808 and parameters: {'learning_rate': 0.2193649153677726, 'max_leaf_nodes': 191, 'max_depth': 4, 'min_samples_leaf': 48, 'l2_regularization': 0.029930681701074338}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:10,333] Trial 13 finished with value: 0.7123627477872359 and parameters: {'learning_rate': 0.15541368518511411, 'max_leaf_nodes': 83, 'max_depth': 4, 'min_samples_leaf': 56, 'l2_regularization': 1.9943971485602656}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:12,936] Trial 14 finished with value: 0.7097375694491217 and parameters: {'learning_rate': 0.11738620179715475, 'max_leaf_nodes': 71, 'max_depth': 4, 'min_samples_leaf': 66, 'l2_regularization': 1.9510627746235927}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:15,578] Trial 15 finished with value: 0.7120233473593164 and parameters: {'learning_rate': 0.1573952972863454, 'max_leaf_nodes': 63, 'max_depth': 2, 'min_samples_leaf': 137, 'l2_regularization': 1.2883794729063127}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:16,779] Trial 16 finished with value: 0.709753350742144 and parameters: {'learning_rate': 0.2380220404905295, 'max_leaf_nodes': 106, 'max_depth': 4, 'min_samples_leaf': 73, 'l2_regularization': 0.5458479992596226}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:19,420] Trial 17 finished with value: 0.7115631044204618 and parameters: {'learning_rate': 0.14285791572425754, 'max_leaf_nodes': 39, 'max_depth': 3, 'min_samples_leaf': 133, 'l2_regularization': 1.9959748503592927}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:20,454] Trial 18 finished with value: 0.7110105902623569 and parameters: {'learning_rate': 0.24435243683414393, 'max_leaf_nodes': 102, 'max_depth': 5, 'min_samples_leaf': 49, 'l2_regularization': 1.5033606869234784}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:22,749] Trial 19 finished with value: 0.7115737035137448 and parameters: {'learning_rate': 0.16386217110324627, 'max_leaf_nodes': 46, 'max_depth': 2, 'min_samples_leaf': 36, 'l2_regularization': 0.27854982795684247}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:24,085] Trial 20 finished with value: 0.7115226598911415 and parameters: {'learning_rate': 0.25811472631544985, 'max_leaf_nodes': 84, 'max_depth': 5, 'min_samples_leaf': 193, 'l2_regularization': 1.1127173650882314}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:26,551] Trial 21 finished with value: 0.7113395847826819 and parameters: {'learning_rate': 0.16868810940891837, 'max_leaf_nodes': 56, 'max_depth': 2, 'min_samples_leaf': 122, 'l2_regularization': 1.2346424377024223}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:29,074] Trial 22 finished with value: 0.7110165194484414 and parameters: {'learning_rate': 0.1289846741599155, 'max_leaf_nodes': 42, 'max_depth': 3, 'min_samples_leaf': 151, 'l2_regularization': 0.7298606142140921}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:31,426] Trial 23 finished with value: 0.710949807593284 and parameters: {'learning_rate': 0.18103436179794044, 'max_leaf_nodes': 62, 'max_depth': 2, 'min_samples_leaf': 79, 'l2_regularization': 1.741764732678945}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:34,257] Trial 24 finished with value: 0.7100879485116625 and parameters: {'learning_rate': 0.09740126381163611, 'max_leaf_nodes': 125, 'max_depth': 4, 'min_samples_leaf': 142, 'l2_regularization': 1.512972951425834}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:36,777] Trial 25 finished with value: 0.7114737406144792 and parameters: {'learning_rate': 0.14969325679889767, 'max_leaf_nodes': 89, 'max_depth': 3, 'min_samples_leaf': 123, 'l2_regularization': 1.5557184403725093}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:39,960] Trial 26 finished with value: 0.7095761836522074 and parameters: {'learning_rate': 0.061247315662047, 'max_leaf_nodes': 30, 'max_depth': 5, 'min_samples_leaf': 112, 'l2_regularization': 1.8778171772218468}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:42,258] Trial 27 finished with value: 0.7120001774385276 and parameters: {'learning_rate': 0.18077020250544928, 'max_leaf_nodes': 59, 'max_depth': 2, 'min_samples_leaf': 87, 'l2_regularization': 0.721294932815344}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:43,292] Trial 28 finished with value: 0.7099362645153547 and parameters: {'learning_rate': 0.22617257225225518, 'max_leaf_nodes': 89, 'max_depth': 7, 'min_samples_leaf': 63, 'l2_regularization': 1.1331909538168503}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:44,860] Trial 29 finished with value: 0.7115296594922795 and parameters: {'learning_rate': 0.2638612193373135, 'max_leaf_nodes': 75, 'max_depth': 3, 'min_samples_leaf': 93, 'l2_regularization': 1.4070889026515812}. Best is trial 0 with value: 0.7124924505996589.
# [I 2026-03-18 16:03:46,273] Trial 30 finished with value: 0.7125771105225566 and parameters: {'learning_rate': 0.12960273107096956, 'max_leaf_nodes': 126, 'max_depth': 5, 'min_samples_leaf': 12, 'l2_regularization': 0.21907220405546113}. Best is trial 30 with value: 0.7125771105225566.
# [I 2026-03-18 16:03:47,551] Trial 31 finished with value: 0.7100049512728209 and parameters: {'learning_rate': 0.12755722155580873, 'max_leaf_nodes': 121, 'max_depth': 7, 'min_samples_leaf': 29, 'l2_regularization': 0.2741898940358609}. Best is trial 30 with value: 0.7125771105225566.
# [I 2026-03-18 16:03:49,249] Trial 32 finished with value: 0.7127637574021535 and parameters: {'learning_rate': 0.09426626959606786, 'max_leaf_nodes': 176, 'max_depth': 5, 'min_samples_leaf': 18, 'l2_regularization': 0.15728260773807728}. Best is trial 32 with value: 0.7127637574021535.
# [I 2026-03-18 16:03:51,000] Trial 33 finished with value: 0.7118285975715273 and parameters: {'learning_rate': 0.08506398815546938, 'max_leaf_nodes': 189, 'max_depth': 5, 'min_samples_leaf': 13, 'l2_regularization': 0.1859498486458219}. Best is trial 32 with value: 0.7127637574021535.
# [I 2026-03-18 16:03:54,006] Trial 34 finished with value: 0.7101908032246469 and parameters: {'learning_rate': 0.040110880247387445, 'max_leaf_nodes': 163, 'max_depth': 4, 'min_samples_leaf': 10, 'l2_regularization': 0.41079054329770603}. Best is trial 32 with value: 0.7127637574021535.
# [I 2026-03-18 16:03:55,682] Trial 35 finished with value: 0.7109025537685969 and parameters: {'learning_rate': 0.11045079699058866, 'max_leaf_nodes': 178, 'max_depth': 5, 'min_samples_leaf': 46, 'l2_regularization': 0.1285257701954018}. Best is trial 32 with value: 0.7127637574021535.
# [I 2026-03-18 16:03:56,467] Trial 36 finished with value: 0.7113255159433931 and parameters: {'learning_rate': 0.2985506187587967, 'max_leaf_nodes': 138, 'max_depth': 7, 'min_samples_leaf': 26, 'l2_regularization': 0.5572571506576955}. Best is trial 32 with value: 0.7127637574021535.
# [I 2026-03-18 16:03:58,075] Trial 37 finished with value: 0.710045282117069 and parameters: {'learning_rate': 0.08613844426135865, 'max_leaf_nodes': 162, 'max_depth': 10, 'min_samples_leaf': 21, 'l2_regularization': 0.1710511998648745}. Best is trial 32 with value: 0.7127637574021535.
# [I 2026-03-18 16:03:59,589] Trial 38 finished with value: 0.7109552667194121 and parameters: {'learning_rate': 0.13981064723021383, 'max_leaf_nodes': 211, 'max_depth': 5, 'min_samples_leaf': 40, 'l2_regularization': 0.004506848327172214}. Best is trial 32 with value: 0.7127637574021535.
# [I 2026-03-18 16:04:02,639] Trial 39 finished with value: 0.7033462203307043 and parameters: {'learning_rate': 0.021738283323326446, 'max_leaf_nodes': 150, 'max_depth': 4, 'min_samples_leaf': 59, 'l2_regularization': 0.3739608183397126}. Best is trial 32 with value: 0.7127637574021535.
# [I 2026-03-18 16:04:05,659] Trial 40 finished with value: 0.710084470799545 and parameters: {'learning_rate': 0.0759022462698378, 'max_leaf_nodes': 130, 'max_depth': 6, 'min_samples_leaf': 73, 'l2_regularization': 0.5494540800789252}. Best is trial 32 with value: 0.7127637574021535.
# [I 2026-03-18 16:04:08,066] Trial 41 finished with value: 0.713203887733901 and parameters: {'learning_rate': 0.16357567271115625, 'max_leaf_nodes': 26, 'max_depth': 2, 'min_samples_leaf': 17, 'l2_regularization': 0.8469579680159887}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:10,604] Trial 42 finished with value: 0.712088611576206 and parameters: {'learning_rate': 0.09653344473789655, 'max_leaf_nodes': 27, 'max_depth': 3, 'min_samples_leaf': 19, 'l2_regularization': 0.2380683885912017}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:11,848] Trial 43 finished with value: 0.7089964418942023 and parameters: {'learning_rate': 0.18307422629601963, 'max_leaf_nodes': 19, 'max_depth': 4, 'min_samples_leaf': 36, 'l2_regularization': 0.8636599704212661}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:14,204] Trial 44 finished with value: 0.7041230203250132 and parameters: {'learning_rate': 0.04936572555333682, 'max_leaf_nodes': 33, 'max_depth': 2, 'min_samples_leaf': 19, 'l2_regularization': 0.35911529814398213}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:16,340] Trial 45 finished with value: 0.7122082602798082 and parameters: {'learning_rate': 0.11161554650005773, 'max_leaf_nodes': 113, 'max_depth': 6, 'min_samples_leaf': 53, 'l2_regularization': 0.08310897547903176}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:18,446] Trial 46 finished with value: 0.7119628176472957 and parameters: {'learning_rate': 0.12826781238266152, 'max_leaf_nodes': 50, 'max_depth': 4, 'min_samples_leaf': 40, 'l2_regularization': 0.6347336757588609}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:19,712] Trial 47 finished with value: 0.7130748831277075 and parameters: {'learning_rate': 0.276602094697245, 'max_leaf_nodes': 98, 'max_depth': 3, 'min_samples_leaf': 11, 'l2_regularization': 0.4651261036912697}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:22,125] Trial 48 finished with value: 0.7116986087305894 and parameters: {'learning_rate': 0.2829028346459405, 'max_leaf_nodes': 98, 'max_depth': 2, 'min_samples_leaf': 28, 'l2_regularization': 0.7998270098874163}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:23,897] Trial 49 finished with value: 0.7130278384059742 and parameters: {'learning_rate': 0.2690736490775395, 'max_leaf_nodes': 230, 'max_depth': 3, 'min_samples_leaf': 11, 'l2_regularization': 0.45224661145470013}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:25,851] Trial 50 finished with value: 0.7124939644654971 and parameters: {'learning_rate': 0.2628809550359818, 'max_leaf_nodes': 242, 'max_depth': 3, 'min_samples_leaf': 16, 'l2_regularization': 0.4837356761227259}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:27,598] Trial 51 finished with value: 0.7115686071370841 and parameters: {'learning_rate': 0.26152098805982177, 'max_leaf_nodes': 250, 'max_depth': 3, 'min_samples_leaf': 13, 'l2_regularization': 0.48382628108467396}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:28,967] Trial 52 finished with value: 0.7128098577658115 and parameters: {'learning_rate': 0.27507556380742376, 'max_leaf_nodes': 234, 'max_depth': 3, 'min_samples_leaf': 10, 'l2_regularization': 0.3399521093596093}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:30,275] Trial 53 finished with value: 0.7131205694435091 and parameters: {'learning_rate': 0.2775261764494698, 'max_leaf_nodes': 219, 'max_depth': 3, 'min_samples_leaf': 10, 'l2_regularization': 0.32377043756244434}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:31,669] Trial 54 finished with value: 0.7103651692932372 and parameters: {'learning_rate': 0.28820094216936, 'max_leaf_nodes': 223, 'max_depth': 3, 'min_samples_leaf': 24, 'l2_regularization': 0.6270063768273808}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:33,447] Trial 55 finished with value: 0.7130308824028405 and parameters: {'learning_rate': 0.27692415413945654, 'max_leaf_nodes': 204, 'max_depth': 3, 'min_samples_leaf': 28, 'l2_regularization': 0.3647782283731482}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:34,997] Trial 56 finished with value: 0.7113170898902241 and parameters: {'learning_rate': 0.25034964430301726, 'max_leaf_nodes': 204, 'max_depth': 3, 'min_samples_leaf': 34, 'l2_regularization': 0.33814875875537365}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:37,516] Trial 57 finished with value: 0.712952540397213 and parameters: {'learning_rate': 0.2328428766452242, 'max_leaf_nodes': 233, 'max_depth': 2, 'min_samples_leaf': 10, 'l2_regularization': 0.9561443371992789}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:40,321] Trial 58 finished with value: 0.710440921770884 and parameters: {'learning_rate': 0.23146301144086226, 'max_leaf_nodes': 220, 'max_depth': 2, 'min_samples_leaf': 30, 'l2_regularization': 0.9888553110690105}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:42,330] Trial 59 finished with value: 0.7109768055336891 and parameters: {'learning_rate': 0.27658693074470525, 'max_leaf_nodes': 199, 'max_depth': 2, 'min_samples_leaf': 44, 'l2_regularization': 0.8444205611989818}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:44,895] Trial 60 finished with value: 0.7128404056052805 and parameters: {'learning_rate': 0.21069050770614456, 'max_leaf_nodes': 235, 'max_depth': 2, 'min_samples_leaf': 22, 'l2_regularization': 0.6477092885900702}. Best is trial 41 with value: 0.713203887733901.
# [I 2026-03-18 16:04:47,275] Trial 61 finished with value: 0.7134714243133086 and parameters: {'learning_rate': 0.2071786104716235, 'max_leaf_nodes': 234, 'max_depth': 2, 'min_samples_leaf': 23, 'l2_regularization': 0.9557319023649663}. Best is trial 61 with value: 0.7134714243133086.
# [I 2026-03-18 16:04:49,581] Trial 62 finished with value: 0.7122408894409442 and parameters: {'learning_rate': 0.250547292723455, 'max_leaf_nodes': 248, 'max_depth': 2, 'min_samples_leaf': 31, 'l2_regularization': 1.121784008945857}. Best is trial 61 with value: 0.7134714243133086.
# [I 2026-03-18 16:04:51,859] Trial 63 finished with value: 0.7129499407630714 and parameters: {'learning_rate': 0.20196577065220933, 'max_leaf_nodes': 226, 'max_depth': 2, 'min_samples_leaf': 19, 'l2_regularization': 0.9431030390202793}. Best is trial 61 with value: 0.7134714243133086.
# [I 2026-03-18 16:04:53,446] Trial 64 finished with value: 0.7100428760324862 and parameters: {'learning_rate': 0.2403738077985176, 'max_leaf_nodes': 213, 'max_depth': 3, 'min_samples_leaf': 25, 'l2_regularization': 0.8022980222400358}. Best is trial 61 with value: 0.7134714243133086.
# [I 2026-03-18 16:04:55,575] Trial 65 finished with value: 0.7123205889235462 and parameters: {'learning_rate': 0.269729211004284, 'max_leaf_nodes': 240, 'max_depth': 2, 'min_samples_leaf': 10, 'l2_regularization': 1.0276562145260746}. Best is trial 61 with value: 0.7134714243133086.
# [I 2026-03-18 16:04:56,461] Trial 66 finished with value: 0.7104300372248427 and parameters: {'learning_rate': 0.21873174806355317, 'max_leaf_nodes': 231, 'max_depth': 9, 'min_samples_leaf': 40, 'l2_regularization': 0.4650482426843374}. Best is trial 61 with value: 0.7134714243133086.
# [I 2026-03-18 16:04:58,083] Trial 67 finished with value: 0.710600388181432 and parameters: {'learning_rate': 0.2894051423535473, 'max_leaf_nodes': 256, 'max_depth': 3, 'min_samples_leaf': 174, 'l2_regularization': 1.205098298309947}. Best is trial 61 with value: 0.7134714243133086.
# [I 2026-03-18 16:05:00,389] Trial 68 finished with value: 0.7135134731304481 and parameters: {'learning_rate': 0.2513303179657189, 'max_leaf_nodes': 196, 'max_depth': 2, 'min_samples_leaf': 17, 'l2_regularization': 0.7537922484583381}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:02,152] Trial 69 finished with value: 0.713050156720817 and parameters: {'learning_rate': 0.25192110389872635, 'max_leaf_nodes': 197, 'max_depth': 3, 'min_samples_leaf': 34, 'l2_regularization': 0.7546582222136033}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:04,110] Trial 70 finished with value: 0.7100019903785248 and parameters: {'learning_rate': 0.2500797906586104, 'max_leaf_nodes': 190, 'max_depth': 3, 'min_samples_leaf': 53, 'l2_regularization': 1.0416565182845674}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:05,472] Trial 71 finished with value: 0.710904435177587 and parameters: {'learning_rate': 0.2928288470378208, 'max_leaf_nodes': 203, 'max_depth': 3, 'min_samples_leaf': 33, 'l2_regularization': 0.7616306897101915}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:07,631] Trial 72 finished with value: 0.7111527050434957 and parameters: {'learning_rate': 0.2721873325065859, 'max_leaf_nodes': 182, 'max_depth': 2, 'min_samples_leaf': 25, 'l2_regularization': 0.6719532522807816}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:09,063] Trial 73 finished with value: 0.711917908985474 and parameters: {'learning_rate': 0.2558648202793605, 'max_leaf_nodes': 219, 'max_depth': 3, 'min_samples_leaf': 16, 'l2_regularization': 0.5315598028706714}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:10,222] Trial 74 finished with value: 0.7110868721063455 and parameters: {'learning_rate': 0.26732576289924437, 'max_leaf_nodes': 196, 'max_depth': 4, 'min_samples_leaf': 21, 'l2_regularization': 0.5892886200518974}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:11,358] Trial 75 finished with value: 0.7117522093965784 and parameters: {'learning_rate': 0.2806387964604265, 'max_leaf_nodes': 206, 'max_depth': 3, 'min_samples_leaf': 16, 'l2_regularization': 0.40681529115623455}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:13,967] Trial 76 finished with value: 0.712220942401711 and parameters: {'learning_rate': 0.19011874911204857, 'max_leaf_nodes': 170, 'max_depth': 2, 'min_samples_leaf': 38, 'l2_regularization': 0.8905016874470763}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:15,737] Trial 77 finished with value: 0.7108221772110488 and parameters: {'learning_rate': 0.2218511634391218, 'max_leaf_nodes': 210, 'max_depth': 3, 'min_samples_leaf': 44, 'l2_regularization': 0.7344210105153542}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:17,004] Trial 78 finished with value: 0.7096214528037035 and parameters: {'learning_rate': 0.29904678446630883, 'max_leaf_nodes': 243, 'max_depth': 4, 'min_samples_leaf': 31, 'l2_regularization': 0.7993351569736986}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:19,498] Trial 79 finished with value: 0.712477972074433 and parameters: {'learning_rate': 0.16944480933487066, 'max_leaf_nodes': 153, 'max_depth': 2, 'min_samples_leaf': 25, 'l2_regularization': 0.30100200098500124}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:21,825] Trial 80 finished with value: 0.7132882489614237 and parameters: {'learning_rate': 0.24350439193833245, 'max_leaf_nodes': 183, 'max_depth': 2, 'min_samples_leaf': 17, 'l2_regularization': 0.891806096654979}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:24,089] Trial 81 finished with value: 0.7120441456336768 and parameters: {'learning_rate': 0.242336615348963, 'max_leaf_nodes': 183, 'max_depth': 2, 'min_samples_leaf': 15, 'l2_regularization': 0.9077304389652604}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:26,316] Trial 82 finished with value: 0.7123521659528841 and parameters: {'learning_rate': 0.2537236094443946, 'max_leaf_nodes': 194, 'max_depth': 2, 'min_samples_leaf': 19, 'l2_regularization': 0.6852206541682435}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:27,604] Trial 83 finished with value: 0.7124012091243905 and parameters: {'learning_rate': 0.28285492147904534, 'max_leaf_nodes': 220, 'max_depth': 3, 'min_samples_leaf': 29, 'l2_regularization': 1.048348863312125}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:29,910] Trial 84 finished with value: 0.7111369584026481 and parameters: {'learning_rate': 0.2368411152667204, 'max_leaf_nodes': 186, 'max_depth': 2, 'min_samples_leaf': 108, 'l2_regularization': 0.8330702918858534}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:31,209] Trial 85 finished with value: 0.7114471914801593 and parameters: {'learning_rate': 0.2451999786072499, 'max_leaf_nodes': 216, 'max_depth': 3, 'min_samples_leaf': 14, 'l2_regularization': 0.4332196908554263}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:33,511] Trial 86 finished with value: 0.7128400957776193 and parameters: {'learning_rate': 0.21210328393740388, 'max_leaf_nodes': 201, 'max_depth': 2, 'min_samples_leaf': 23, 'l2_regularization': 0.516674304258772}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:34,843] Trial 87 finished with value: 0.7121075827900112 and parameters: {'learning_rate': 0.2650976300120013, 'max_leaf_nodes': 173, 'max_depth': 3, 'min_samples_leaf': 34, 'l2_regularization': 0.2309239097114062}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:35,920] Trial 88 finished with value: 0.7106250849367861 and parameters: {'learning_rate': 0.22749733692413118, 'max_leaf_nodes': 69, 'max_depth': 4, 'min_samples_leaf': 16, 'l2_regularization': 0.5865982617520098}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:38,334] Trial 89 finished with value: 0.7121119939321411 and parameters: {'learning_rate': 0.2602252049986778, 'max_leaf_nodes': 226, 'max_depth': 2, 'min_samples_leaf': 27, 'l2_regularization': 0.9701022177884925}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:39,602] Trial 90 finished with value: 0.71123831681767 and parameters: {'learning_rate': 0.27288779056501355, 'max_leaf_nodes': 209, 'max_depth': 3, 'min_samples_leaf': 10, 'l2_regularization': 1.0872934524386209}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:41,879] Trial 91 finished with value: 0.7117505607948971 and parameters: {'learning_rate': 0.2343699744797043, 'max_leaf_nodes': 234, 'max_depth': 2, 'min_samples_leaf': 21, 'l2_regularization': 1.166467481235033}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:43,587] Trial 92 finished with value: 0.7123684389868516 and parameters: {'learning_rate': 0.20377344330728514, 'max_leaf_nodes': 137, 'max_depth': 2, 'min_samples_leaf': 10, 'l2_regularization': 0.9348454108485263}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:45,656] Trial 93 finished with value: 0.7120863970676936 and parameters: {'learning_rate': 0.2451113901485504, 'max_leaf_nodes': 238, 'max_depth': 2, 'min_samples_leaf': 14, 'l2_regularization': 0.7550659151987454}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:47,910] Trial 94 finished with value: 0.712864772130315 and parameters: {'learning_rate': 0.2175597846789091, 'max_leaf_nodes': 227, 'max_depth': 2, 'min_samples_leaf': 21, 'l2_regularization': 0.9732040218232252}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:49,405] Trial 95 finished with value: 0.7122861531894279 and parameters: {'learning_rate': 0.23160122153988663, 'max_leaf_nodes': 215, 'max_depth': 3, 'min_samples_leaf': 17, 'l2_regularization': 0.8660077960249025}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:51,416] Trial 96 finished with value: 0.7114253154288828 and parameters: {'learning_rate': 0.259369228293417, 'max_leaf_nodes': 248, 'max_depth': 2, 'min_samples_leaf': 28, 'l2_regularization': 0.27811835300217197}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:53,308] Trial 97 finished with value: 0.7120755721144892 and parameters: {'learning_rate': 0.1922375635830628, 'max_leaf_nodes': 158, 'max_depth': 3, 'min_samples_leaf': 37, 'l2_regularization': 1.0750590064187096}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:54,055] Trial 98 finished with value: 0.7075823913535935 and parameters: {'learning_rate': 0.2780803938271942, 'max_leaf_nodes': 198, 'max_depth': 8, 'min_samples_leaf': 23, 'l2_regularization': 0.3857093001992259}. Best is trial 68 with value: 0.7135134731304481.
# [I 2026-03-18 16:05:54,907] Trial 99 finished with value: 0.7130725001432301 and parameters: {'learning_rate': 0.2699565777278049, 'max_leaf_nodes': 193, 'max_depth': 4, 'min_samples_leaf': 13, 'l2_regularization': 1.2851972752208085}. Best is trial 68 with value: 0.7135134731304481.
# <style type="text/css">
# #T_654ee_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_654ee_row1_col0 {
#   background-color: #b8de29;
#   color: #000000;
# }
# #T_654ee_row2_col0 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_654ee_row3_col0 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_654ee_row4_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_654ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_654ee_level0_col0" class="col_heading level0 col0" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_654ee_level0_row0" class="row_heading level0 row0" >68</th>
#       <td id="T_654ee_row0_col0" class="data row0 col0" >0.713513</td>
#     </tr>
#     <tr>
#       <th id="T_654ee_level0_row1" class="row_heading level0 row1" >61</th>
#       <td id="T_654ee_row1_col0" class="data row1 col0" >0.713471</td>
#     </tr>
#     <tr>
#       <th id="T_654ee_level0_row2" class="row_heading level0 row2" >80</th>
#       <td id="T_654ee_row2_col0" class="data row2 col0" >0.713288</td>
#     </tr>
#     <tr>
#       <th id="T_654ee_level0_row3" class="row_heading level0 row3" >41</th>
#       <td id="T_654ee_row3_col0" class="data row3 col0" >0.713204</td>
#     </tr>
#     <tr>
#       <th id="T_654ee_level0_row4" class="row_heading level0 row4" >53</th>
#       <td id="T_654ee_row4_col0" class="data row4 col0" >0.713121</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_q3.head()
# Out:
#    number     value             datetime_start          datetime_complete  \
# 0       0  0.712492 2026-03-18 16:02:42.207587 2026-03-18 16:02:45.956667
# 1       1  0.711439 2026-03-18 16:02:45.957724 2026-03-18 16:02:46.952204
# 2       2  0.709322 2026-03-18 16:02:46.952817 2026-03-18 16:02:49.353577
# 3       3  0.710623 2026-03-18 16:02:49.354243 2026-03-18 16:02:50.842510
# 4       4  0.699219 2026-03-18 16:02:50.843126 2026-03-18 16:02:53.554110
#
#                 duration  params_l2_regularization  params_learning_rate  \
# 0 0 days 00:00:03.749080                  0.092846              0.286601
# 1 0 days 00:00:00.994480                  0.298326              0.279677
# 2 0 days 00:00:02.400760                  1.654473              0.101281
# 3 0 days 00:00:01.488267                  1.314552              0.296046
# 4 0 days 00:00:02.710984                  1.744619              0.030027
#
#    params_max_depth  params_max_leaf_nodes  params_min_samples_leaf     state
# 0                 2                     34                       70  COMPLETE
# 1                 6                     77                       93  COMPLETE
# 2                10                    229                      173  COMPLETE
# 3                 3                    147                       82  COMPLETE
# 4                 3                    215                      100  COMPLETE

# %% [markdown]
# ### Problem 3 Graded Answer
#
# Set `a3` to the mean F1 score of the best model found.

# %%
 # Your answer here

a3 = (df_q3['value'].max())                     # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a3 = {a3:.4f}')
# Out:
# a3 = 0.7135

# %% [markdown]
# ## Problem 4: Final Model Evaluation on Test Set
#
# In this problem, you will take the best hyperparameter configuration you found in your earlier experiments (Randomized Search or Optuna) and fully evaluate the resulting model on the test set.
#
# **Background:**
# When performing hyperparameter tuning, we typically optimize for a single metric (e.g., F1). However, before deployment, it is essential to check **all relevant metrics** on the final test set to understand the model’s behavior in a balanced way.
#
# **Instructions:**
#
# 1. Take the best hyperparameters you found in Problems 2 or 3 and apply them to your `pipelined_model`.
# 2. Re-train this final tuned model on the **entire training set** (not just the folds).
# 3. Evaluate the final model on the heldout **test set**, reporting the following metrics:
#
#    * Precision
#    * Recall
#    * F1 score
#    * Balanced accuracy
# 4. Use `classification_report` **on the test set** to print precision, recall, and F1 score, and use `balanced_accuracy_score` separately to calculate and print balanced accuracy.
# 5. Answer the graded questions.
#
# **Note:** We evaluate the metrics on the test set because it was never seen during training or hyperparameter tuning. This gives us an unbiased estimate of how the model will perform on truly unseen data. Evaluating on the training set would be misleading, because the model has already learned from that data and could appear artificially good.

# %%
optunastudy.best_trial.params
# Out:
# {'learning_rate': 0.2513303179657189,
#  'max_leaf_nodes': 196,
#  'max_depth': 2,
#  'min_samples_leaf': 17,
#  'l2_regularization': 0.7537922484583381}

# %%
# Your code here
q4_params_to_use = {
    "gb__learning_rate": optunastudy.best_params["learning_rate"] 
    , "gb__max_leaf_nodes": optunastudy.best_params["max_leaf_nodes"] 
    , "gb__max_depth": optunastudy.best_params["max_depth"]
    , "gb__min_samples_leaf": optunastudy.best_params["min_samples_leaf"] 
    , "gb__l2_regularization": optunastudy.best_params["l2_regularization"]
}


q4_model = pipelined_model.set_params(**q4_params_to_use)

q4_model.fit(X_train, y_train)

q4_pred = q4_model.predict(X_test)

##---

q4_report = classification_report(y_test, q4_pred, output_dict=True)
q4_balanced_acc = balanced_accuracy_score(y_test, q4_pred)

# %%
df_q4 = (pd.DataFrame(q4_report))
# Out:
# 0.781550668557546

# %%
print(q4_report['accuracy'])
# Out:
# 0.8359095096734569

# %%
print(q4_balanced_acc )
# Out:
# 0.8477296229387927

# %% [markdown]
# ### Problem 4 Graded Questions
#
# - Set `a4a` to the balanced accuracy score of the best model.
# - Set `a4b` to the macro average precision of this model.
# - Set `a4c` to the macro average recall score of the this model.
#
# **Note:** Macro average takes the mean of each class’s precision/recall without considering how many samples each class has, which is appropriate for a balanced evaluation.

# %%
 # Your answer here

a4a = q4_balanced_acc                     # replace 0 with your answer, use variable or expression from above

# %%
# DO NOT change this cell in any way

print(f'a4a = {a4a:.4f}')
# Out:
# a4a = 0.8477

# %%
 # Your answer here

a4b = float(df_q4.loc[(df_q4.index == 'precision'), 'macro avg'].iloc[0])              # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a4b = {a4b:.4f}')
# Out:
# a4b = 0.7816

# %%
 # Your answer here

a4c = float(df_q4.loc[(df_q4.index == 'recall'), 'macro avg'].iloc[0])                     # replace 0 with your answer, may copy from the displayed results

# %%
# DO NOT change this cell in any way

print(f'a4c = {a4c:.4f}')
# Out:
# a4c = 0.8477

# %% [markdown]
# ## Problem 5: Understanding Precision, Recall, F1, and Balanced Accuracy
#
# **Tutorial**
#
# In binary classification, you will often evaluate these key metrics:
#
# * **Precision**: *Of all the positive predictions the model made, how many were actually correct?*
#
#   * High precision = few false positives
#   * Low precision = many false positives
#
# * **Recall**: *Of all the actual positive cases, how many did the model correctly identify?*
#
#   * High recall = few false negatives
#   * Low recall = many false negatives
#
# * **F1 score**: The harmonic mean of precision and recall, which balances them in a single measure.
#
#   * F1 is **highest** when precision and recall are both high and similar in value.
#   * If precision and recall are unbalanced, F1 will drop to reflect that imbalance.
#
# * **Balanced accuracy**: The average of recall across both classes (positive and negative).
#
#   * It ensures the classifier is performing reasonably well on *both* groups, correcting for class imbalance.
#   * Balanced accuracy is especially important if the classes are very unequal in size.
#
# **Typical trade-offs to remember:**
#
# * **Higher recall, lower precision**: the model finds most true positives but also mislabels some negatives as positives
# * **Higher precision, lower recall**: the model is strict about positive predictions, but misses some true positives
# * **Balanced precision and recall (good F1)**: a practical compromise
# * **Balanced accuracy**: checks fairness across both classes

# %% [markdown]
# ###  Problem 5 Graded Question (multiple choice)
#
# A bank uses your model to identify customers earning over $50K for a premium product invitation. Based on your final test set evaluation, including macro-averaged precision and recall, which of the following best describes what might happen?
#
# (1) The bank will miss some eligible high-income customers, but will avoid marketing mistakes by sending invitations only to those it is  confident about.
#
# (2) The bank will successfully reach most high-income customers, but will also waste resources sending invitations to some low-income customers.
#
# (3) The bank will perfectly identify all high-income and low-income customers, resulting in no wasted invitations and no missed opportunities.

# %%
 # Your answer here

a5 = 2                     # replace 0 with one of 1, 2, or 3

# %%
# DO NOT change this cell in any way

print(f'a5 = {a5}')
# Out:
# a5 = 2

# %% [markdown]
# ### Appendix One: Feature Engineering
#
# Here are some practical feature-engineering tweaks worth considering (beyond simply ordinal-encoding the categoricals)
#
# | Feature(s)                                                           | Why the tweak can help                                                                                                                                                     | How to do it (quick version)                                                                                                                                                    | Keep / drop?      |
# | -------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------- |
# | **`fnlwgt`**                                                         | Survey sampling weight, not a predictor. Leaving it in often lets the model “cheat.”                                                                                       | `df = df.drop(columns=["fnlwgt"])`                                                                                                                                              | **Drop**          |
# | **`education` *vs.* `education-num`**                                | They encode the **same** information twice (categorical label and its ordinal rank). Keeping both is redundant and can cause leakage of a perfectly predictive feature.    | Usually keep **only one**. For tree models `education-num` is simplest: `df = df.drop(columns=["education"])`                                                                   | **Drop one**      |
# | **`capital-gain`, `capital-loss`**                                   | Highly skewed; most values are zero with a long upper tail. The sign (gain vs. loss) matters, but treating them separately wastes a feature slot.                          | 1) Combine: `df["capital_net"] = df["capital-gain"] - df["capital-loss"]`; 2) Log-transform to reduce skew: `df["capital_net_log"] = np.log1p(df["capital_net"].clip(lower=0))` | Replace originals |
# | **`age`, `hours-per-week`**                                          | Continuous but with natural plateaus—trees handle splits fine, yet log or square-root scaling can soften extreme values; bucketing makes partial-dependence plots clearer. | Simple bucket: `df["age_bin"] = pd.cut(df["age"], bins=[16,25,35,45,55,65,90])` (optional)                                                                                      | Optional          |
# | **Missing categories** (`workclass`, `occupation`, `native-country`) | HGB handles `-1`/`-2` codes fine, but you may want *explicit* “Missing” bucket for interpretability.                                                                       | Use `encoded_missing_value=-2` during encoding.                                                                                                            | Keep as is        |
# | **Rare categories in `native-country`**                              | Hundreds of low-frequency countries dilute signal; grouping boosts stability.                                                                                              | Map infrequent categories to “Other”:                                                                                                                                           |                   |
#
#
# #### Minimum set of tweaks (good baseline, low effort)
#
# 1. **Drop `fnlwgt`.**
# 2. **Keep `education-num`, drop `education`.**
# 3. **Combine `capital-gain` and `capital-loss` into `capital_net`** (optionally add a log-scaled version).
# 4. Leave other numeric/categorical features as is; your histogram-GBDT will cope.
